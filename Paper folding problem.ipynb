# %%
# Code to calculate the thickness when the paper is folded 43 times

THICKNESS = 0.00008  # Initial thickness of the paper in meters
FOLDS = 43  # Number of folds

folded_thickness = THICKNESS * (2 ** FOLDS)

print("Thickness: {:.2f} meters".format(folded_thickness))


#Unit Conversion 
print("Thickness: {: .2f} kilometers".format(folded_thickness / 1000))

#Using for statement
THICKNESS = 0.00008  # Initial thickness of the paper in meters
FOLDS = 43  # Number of folds

folded_thickness = THICKNESS

for _ in range(FOLDS):
    folded_thickness *= 2  # Double the thickness each time

print("Thickness: {:.2f} meters".format(folded_thickness))

#Time taken using a for statement
import time
start = time.time()
#####
THICKNESS = 0.00008  # Initial thickness of the paper in meters
FOLDS = 43  # Number of folds

folded_thickness = THICKNESS

for _ in range(FOLDS):
    folded_thickness *= 2  # Double the thickness each time

print("Thickness: {:.2f} meters".format(folded_thickness))
#####
elapsed_time = time.time() - start
print("time : {}[s]".format(elapsed_time))


#Time taken using  exponentiation arithmetic operators
import time
start = time.time()
#####
THICKNESS = 0.00008  # Initial thickness of the paper in meters
FOLDS = 43  # Number of folds

folded_thickness = THICKNESS * (2 ** FOLDS)

print("Thickness: {:.2f} meters".format(folded_thickness))
#####
elapsed_time = time.time() - start
print("time : {}[s]".format(elapsed_time))


import matplotlib.pyplot as plt

# Code to calculate the thickness when the paper is folded 43 times using a for loop

THICKNESS = 0.00008  # Initial thickness of the paper in meters
FOLDS = 43  # Number of folds

folded_thickness = THICKNESS
thickness_list = [THICKNESS]  # List to store thickness at each fold

for _ in range(FOLDS):
    folded_thickness *= 2  # Double the thickness each time
    thickness_list.append(folded_thickness)

# Plot of the thickness growth
plt.figure(figsize=(10, 5))
plt.plot(range(FOLDS + 1), thickness_list, marker='x', linestyle='-', color='b')
plt.xlabel("Number of Folds")
plt.ylabel("Thickness (meters)")
plt.title("Growth of Paper Thickness with Folding")
plt.grid(True)
plt.show()

print("Thickness after 43 folds: {:.2f} meters".format(folded_thickness))


#Saving to a list
import matplotlib.pyplot as plt

# Code to calculate the thickness when the paper is folded 43 times using a for loop

THICKNESS = 0.00008  # Initial thickness of the paper in meters
FOLDS = 43  # Number of folds

folded_thickness = THICKNESS
thickness_list = []  # List to store thickness at each fold

# Record initial thickness
thickness_list.append(folded_thickness)

for _ in range(FOLDS):
    folded_thickness *= 2  # Double the thickness each time
    thickness_list.append(folded_thickness)

# Verifying the number of recorded values
print("Total recorded values:", len(thickness_list))

# Plot the thickness growth
plt.figure(figsize=(10, 5))
plt.plot(range(FOLDS + 1), thickness_list, marker='x', linestyle='', color='b')
plt.xlabel("Number of Folds")
plt.ylabel("Thickness (meters)")
plt.title("Growth of Paper Thickness with Folding")
plt.grid(True)
plt.show()

print("Thickness after 43 folds: {:.2f} meters".format(folded_thickness))


#Displaying the line graph and expalaining how the thickness change
import matplotlib.pyplot as plt

# Code to calculate the thickness when the paper is folded 43 times using a for loop

THICKNESS = 0.00008  # Initial thickness of the paper in meters
FOLDS = 43  # Number of folds

folded_thickness = THICKNESS
thickness_list = []  # List to store thickness at each fold

# Record initial thickness
thickness_list.append(folded_thickness)

for _ in range(FOLDS):
    folded_thickness *= 2  # Double the thickness each time
    thickness_list.append(folded_thickness)

# Verify the number of recorded values
print("Total recorded values:", len(thickness_list))

# Display the graph. Title and axis label name.
plt.title("Thickness of Folded Paper")
plt.xlabel("Number of Folds")
plt.ylabel("Thickness [m]")
plt.plot(thickness_list)  # Enter the variable name of the list
plt.show()

print("Thickness after 43 folds: {:.2f} meters".format(folded_thickness))

# Explanation of thickness change
print("The thickness increases exponentially as the paper is folded. Initially, the growth is slow, but after multiple folds, the thickness rapidly increases, reaching astronomical levels.")


import matplotlib.pyplot as plt

# Code to calculate the thickness when the paper is folded 43 times using a for loop

THICKNESS = 0.00008  # Initial thickness of the paper in meters
FOLDS = 43  # Number of folds

folded_thickness = THICKNESS
thickness_list = []  # List to store thickness at each fold

# Record initial thickness
thickness_list.append(folded_thickness)

for _ in range(FOLDS):
    folded_thickness *= 2  # Double the thickness each time
    thickness_list.append(folded_thickness)

# Verify the number of recorded values
print("Total recorded values:", len(thickness_list))

# Customized Graph
plt.figure(figsize=(10, 5))


import matplotlib.pyplot as plt

# Code to calculate the thickness when the paper is folded 43 times using a for loop

THICKNESS = 0.00008  # Initial thickness of the paper in meters
FOLDS = 43  # Number of folds

folded_thickness = THICKNESS
thickness_list = []  # List to store thickness at each fold

# Record initial thickness
thickness_list.append(folded_thickness)

for _ in range(FOLDS):
    folded_thickness *= 2  # Double the thickness each time
    thickness_list.append(folded_thickness)

# Verify the number of recorded values
print("Total recorded values:", len(thickness_list))

# Customized Graph
plt.figure(figsize=(10, 5))
plt.subplot(1, 3, 3)
plt.title("Green Thick Line")
plt.xlabel("Number of Folds")
plt.ylabel("Thickness [m]")
plt.plot(thickness_list, color='green', linewidth=3)

plt.tight_layout()
plt.show()

print("Thickness after 43 folds: {:.2f} meters".format(folded_thickness))


import matplotlib.pyplot as plt

# Code to calculate the thickness when the paper is folded 43 times using a for loop

THICKNESS = 0.00008  # Initial thickness of the paper in meters
FOLDS = 43  # Number of folds

folded_thickness = THICKNESS
thickness_list = []  # List to store thickness at each fold

# Record initial thickness
thickness_list.append(folded_thickness)

for _ in range(FOLDS):
    folded_thickness *= 2  # Double the thickness each time
    thickness_list.append(folded_thickness)

# Verify the number of recorded values
print("Total recorded values:", len(thickness_list))

# Customized Graph
plt.figure(figsize=(10, 5))
plt.subplot(1, 3, 3)
plt.title("Green Thick Line")
plt.xlabel("Number of Folds")
plt.ylabel("Thickness [m]")
plt.tick_params(labelsize=20)
plt.plot(thickness_list, color='green', linewidth=3)

plt.tight_layout()
plt.show()

print("Thickness after 43 folds: {:.2f} meters".format(folded_thickness))
